# %%
import pandas as pd
import numpy as np
import random

# %%
lista = [
    'hyacinthe-lovo-v3.wav',
    'lola-murf.wav',
    'neural2B-GCP.wav',
    'alonso-naturalreader.wav',
    'antonio-murf.wav',
    'neural2A-GCP.wav',
    'adam-evenlabs-pitchmodifield.wav',
    'francisca-lovo-v2.wav',
    'lautaro-lovo-v3.wav',
    'veronica-lovo-v4-pitchmodified.wav',
    'antoni-evenlabs-v3.wav',
    'lia-lovo-pitchmodified.wav',
    'julieta-lovo-v2-pitchmodified.wav',
    'neural2C-GCP-linguistico-speed0.78-pitchmodified.wav',
    'rosa-lovo-pitchmodified.wav',
    'elvira-lovo-pitchmodified.wav',
    'agata-lovo-pitchmodified.wav',
    'antoni-evenlabs-linguistico-v2.wav',
    'neural2C-GCP-linguistico-speed0.78-pitchmodified-v2.wav',
    'neural2C-pitchmodified-speedmodified.wav'
]

# %%
# Reordenar la lista aleatoriamente
random.shuffle(lista)

# Crear un DataFrame con la lista reordenada
df = pd.DataFrame({'filename': lista})

# Agregar un índice
df.index = range(1, len(df) + 1)

df
# Out:
#                                              filename
# 1                            alonso-naturalreader.wav
# 2                                 lautaro-lovo-v3.wav
# 3                               hyacinthe-lovo-v3.wav
# 4                    adam-evenlabs-pitchmodifield.wav
# 5                                    neural2B-GCP.wav
# 6            neural2C-pitchmodified-speedmodified.wav
# 7                  veronica-lovo-v4-pitchmodified.wav
# 8                        agata-lovo-pitchmodified.wav
# 9                                       lola-murf.wav
# 10  neural2C-GCP-linguistico-speed0.78-pitchmodifi...
# 11                 antoni-evenlabs-linguistico-v2.wav
# 12                  julieta-lovo-v2-pitchmodified.wav
# 13  neural2C-GCP-linguistico-speed0.78-pitchmodifi...
# 14                             antoni-evenlabs-v3.wav
# 15                                   neural2A-GCP.wav
# 16                        rosa-lovo-pitchmodified.wav
# ...

# %%
# Guardar el DataFrame como un archivo CSV
df.to_excel('order_filename.ods', index_label='ID', engine='odf')
df.to_csv('order_filename.csv', index_label='ID')
